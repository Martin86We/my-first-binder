# %% [markdown]
# <a href="https://colab.research.google.com/github/Martin86We/my-first-binder/blob/main/Datensatz_mit_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ![Dataset with keras.PNG](data:image/png;base64,...)

# %%
# Create a dataset.
dataset = keras.preprocessing.image_dataset_from_directory(
  '/content/drive/MyDrive/Colab Notebooks/Kursmaterialien/Masterarbeit_data/Screw_dataset_mini', batch_size=1, image_size=(28, 28))

# For demonstration, iterate over the batches yielded by the dataset.
for data, labels in dataset:
   print(data.shape)  # (64, 200, 200, 3)
   print(data.dtype)  # float32
   print(labels.shape)  # (64,)
   print(labels.dtype)  # int32
# Out:
# Found 5 files belonging to 5 classes.
# (1, 28, 28, 3)
# <dtype: 'float32'>
# (1,)
# <dtype: 'int32'>
# (1, 28, 28, 3)
# <dtype: 'float32'>
# (1,)
# <dtype: 'int32'>
# (1, 28, 28, 3)
# <dtype: 'float32'>
# (1,)
# <dtype: 'int32'>
# (1, 28, 28, 3)
# <dtype: 'float32'>
# (1,)
# <dtype: 'int32'>
# (1, 28, 28, 3)
# <dtype: 'float32'>
# (1,)
# <dtype: 'int32'>

# %%
import numpy as np

def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

# %%
data.shape
labels
# Out:
# <tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>

# %%
gray=rgb2gray(data[0])

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %%
plt.imshow(data[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
screw_gray = rgb2gray()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-6c521763bb9e> in <module>()
# ----> 1 screw_gray = rgb2gray(imread('Screw_dataset_mini/Kreuz_philips/Kreuz_philips_000.jpg'))
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in imread(fname, format)
#    1462             raise ValueError('Only know how to handle PNG; with Pillow '
#    1463                              'installed, Matplotlib can handle more images')
# -> 1464         with Image.open(fname) as image:
#    1465             return pil_to_array(image)
#    1466     from matplotlib import _png
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# ...
